# %% [markdown]
# TO DO:
#
# Разработайте модель предсказания оттока клиента из банка. На вход Вы имеете размеченный датасет, на выходе должны предоставить обученную модель, которую рекомендуете к использованию.
#
# Основные шаги прописаны ниже - они должны быть выполнены. Задание творческое - Вы вольны производить все операции с данными, которые считаете нужными. Возникающие вопросы Вам придется решать самостоятельно. Постарайтесь применить максимум знаний, которыми обладаете в рамках построения классических моделей на табличных данных.
#
# Пожалуйста, структурируйте ноутбук,  пишите комментарии. Перед отправкой решения убедитесь, что код запускается от начала до конца.
#
# 1. Загрузите данные из предложенного файла
# 2. Признаки анонимизированы.Целевой признак: target = факт ухода клиента из банка
# 3. Определите тип задачи: регрессия или классификация. Какие метрики качества потенциально можно использовать? Выберите метрики для определения качества данной модели.
# 4. Проведите предобработку данных, если это необходимо. Исследуйте распределения.
# 5. Кодируйте и масштабируйте признаки, если считаете нужным.
# 6. Разбейте выборку на train/test/valid
# 7. Выберите не менее двух подходов к построению модели: дерево решений, случайный лес, линейная модель, бустинг.
# 8. В процессе разработки моделей проведите отбор признаков любыми методиками, которые считаете нужными.
# 9. Выведите итоговый результат: обязательны значения метрик на выбранных моделях, выбор лучшей модели и итоговый набор признаков.
