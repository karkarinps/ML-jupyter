# %%
# грузим пандас, грузим датасет
import pandas as pd
dataset = pd.read_csv('C:\\Users\\Uldum\\Downloads\\housing_market_dataset.csv')

# %%
# выводим данные из сотого индекса
dataset.loc[100]
# Out:
# url                              https://move.ru/objects/prodaetsya_2-komnatnay...
# Заголовок                          Продам 2-комнатную квартиру, 51 м², Зверево, 5Б
# Новостройка                                                                    NaN
# Этап строительства                                                             NaN
# Год постройки                                                               2017.0
# Класс жилья                                                                    NaN
# МЦК                                                                МЦК Кутузовская
# Кол-во просмотров                                                              196
# Кол-во просмотров сегодня                                                      1.0
# Описание                         г.Москва,п.Новофедоровское ул.Десятинная д.5  ...
# Информация                       Продам 2-комнатную квартиру общей площадью 51 ...
# ...

# %%
# выводим данные с 1000 по 2000 инлексы, включительно! (не как в Python)
dataset.loc[1000:2000]
# Out:
#                                                     url  \
# 1000  https://move.ru/objects/prodaetsya_1-komnatnay...
# 1001  https://move.ru/objects/prodaetsya_1-komnatnay...
# 1002  https://move.ru/objects/prodaetsya_2-komnatnay...
# 1003  https://move.ru/objects/prodaetsya_1-komnatnay...
# 1004  https://move.ru/objects/prodaetsya_2-komnatnay...
# ...                                                 ...
# 1996  https://move.ru/objects/prodaetsya_3-komnatnay...
# 1997  https://move.ru/objects/prodaetsya_2-komnatnay...
# 1998  https://move.ru/objects/prodaetsya_2-komnatnay...
# 1999  https://move.ru/objects/prodaetsya_3-komnatnay...
# 2000  https://move.ru/objects/prodaetsya_2-komnatnay...
#
#                                               Заголовок  \
# 1000      Продается 1-комнатная квартира, 47 м², Москва
# 1001        Продаем 1-комнатную квартиру, 59 м², Москва
# 1002         Продаю 2-комнатную квартиру, 74 м², Москва
# 1003        Продажа 1-комнатной квартиры, 62 м², Москва
# ...

# %%
# выводим список индексов из датасета
index_list = [209,1,2,5,10,19,354]
dataset.loc[index_list]
# Out:
#                                                    url  \
# 209  https://move.ru/objects/moskva_ulica_obrucheva...
# 1    https://move.ru/objects/prodaetsya_2-komn_kvar...
# 2    https://move.ru/objects/prodaetsya_2-komn_kvar...
# 5    https://move.ru/objects/prodaetsya_3-komn_kvar...
# 10   https://move.ru/objects/moskva_novovatutinskiy...
# 19   https://move.ru/objects/moskva_derevnya_rasska...
# 354  https://move.ru/objects/prodaetsya_1-komn_kvar...
#
#                                              Заголовок  \
# 209  Продается 1-комнатная квартира, 40 м², Москва,...
# 1    Продам 2-комнатную квартиру, 83.2 м², Москва, ...
# 2    Продаю 2-комнатную квартиру, 89.6 м², Москва, ...
# 5    Продам 3-комнатную квартиру, 126.7 м², Москва,...
# 10   Продаю 3-комнатную квартиру, 76 м², Троицк, Но...
# 19   Продаем 2-комнатную квартиру, 65.74 м², Расска...
# 354  Продам 1-комнатную квартиру, 32 м², Москва, См...
#
# ...

# %%
# создаём минисет из описания основного датасета
described_data = dataset.describe()
described_data
# Out:
#        Год постройки  Кол-во просмотров  Кол-во просмотров сегодня  \
# count    7025.000000       13001.000000                7224.000000
# mean     2001.139786          94.524190                   1.844546
# std        25.060692         199.666472                   2.712400
# min      1876.000000           1.000000                   1.000000
# 25%      1979.000000          35.000000                   1.000000
# 50%      2018.000000          65.000000                   1.000000
# 75%      2019.000000          97.000000                   2.000000
# max      2021.000000        5739.000000                  38.000000
#
#        Количество этажей  Количество комнат     Этажность   Номер этажа
# count       12510.000000       13001.000000  13001.000000  13001.000000
# mean           17.488649           1.974848     17.444043      8.624798
# std            19.682982           0.912510      9.728213      6.693463
# min             1.000000           1.000000      1.000000      1.000000
# ...

# %%
# из минисета выводим индекс-строку максимального значения 
described_data.loc['max']
# Out:
# Год постройки                2021.0
# Кол-во просмотров            5739.0
# Кол-во просмотров сегодня      38.0
# Количество этажей            1960.0
# Количество комнат              25.0
# Этажность                     100.0
# Номер этажа                    95.0
# Name: max, dtype: float64

# %%
# из минисета выводим все значения от индекса мин до макс включительно!
described_data.loc['min':'max']
# Out:
#      Год постройки  Кол-во просмотров  Кол-во просмотров сегодня  \
# min         1876.0                1.0                        1.0
# 25%         1979.0               35.0                        1.0
# 50%         2018.0               65.0                        1.0
# 75%         2019.0               97.0                        2.0
# max         2021.0             5739.0                       38.0
#
#      Количество этажей  Количество комнат  Этажность  Номер этажа
# min                1.0                1.0        1.0          1.0
# 25%               12.0                1.0       12.0          3.0
# 50%               16.0                2.0       16.0          7.0
# 75%               22.0                3.0       22.0         12.0
# max             1960.0               25.0      100.0         95.0

# %%
# выводим список строковых индексов из датасета
stat_names = ['min','max']
described_data.loc[stat_names]
# Out:
#      Год постройки  Кол-во просмотров  Кол-во просмотров сегодня  \
# min         1876.0                1.0                        1.0
# max         2021.0             5739.0                       38.0
#
#      Количество этажей  Количество комнат  Этажность  Номер этажа
# min                1.0                1.0        1.0          1.0
# max             1960.0               25.0      100.0         95.0

# %%
# создаём отсортированный по количеству комнат датасет
sorted_dataset = dataset.sort_values('Количество комнат', ascending=False)
sorted_dataset.head()
# Out:
#                                                      url  \
# 321    https://move.ru/objects/moskva_korovinskoe_sho...
# 115    https://move.ru/objects/moskva_poselok_kievski...
# 10914  https://move.ru/objects/moskva_ulica_krylatski...
# 10105  https://move.ru/objects/predstavlyaem_vashemu_...
# 1564   https://move.ru/objects/moskva_gorod_zelenogra...
#
#                                                Заголовок  \
# 321    Продаю пентхаус, 550 м², Москва, шоссе Коровин...
# 115                   Продаю квартиру, 42 м², Москва, 17
# 10914  Продаем квартиру, 410 м², Москва, улица Крылат...
# 10105  Продажа квартиры, 250 м², Москва, улица Остров...
# 1564   Продаю квартиру, 160 м², Зеленоград, Логвиненк...
#
#                         Новостройка Этап строительства  Год постройки  \
# 321                             NaN                NaN         1967.0
# 115                             NaN                NaN            NaN
# ...

# %%
# срез датасета по индексу от 0 до 100 включительно! Лучше не использовать для подсетов, правильный вариант ниже.
sorted_dataset.loc[:100]
# Out:
#                                                      url  \
# 321    https://move.ru/objects/moskva_korovinskoe_sho...
# 115    https://move.ru/objects/moskva_poselok_kievski...
# 10914  https://move.ru/objects/moskva_ulica_krylatski...
# 10105  https://move.ru/objects/predstavlyaem_vashemu_...
# 1564   https://move.ru/objects/moskva_gorod_zelenogra...
# ...                                                  ...
# 116    https://move.ru/objects/moskva_poselok_kievski...
# 112    https://move.ru/objects/moskva_poselok_novofed...
# 108    https://move.ru/objects/moskva_poselok_znamya_...
# 106    https://move.ru/objects/moskva_ul_lipovyy_park...
# 100    https://move.ru/objects/prodaetsya_2-komnatnay...
#
#                                                Заголовок  \
# 321    Продаю пентхаус, 550 м², Москва, шоссе Коровин...
# 115                   Продаю квартиру, 42 м², Москва, 17
# 10914  Продаем квартиру, 410 м², Москва, улица Крылат...
# ...

# %%
# срез от 0 до 100 по индексу в подсете
sorted_dataset.iloc[:100]
# Out:
#                                                      url  \
# 321    https://move.ru/objects/moskva_korovinskoe_sho...
# 115    https://move.ru/objects/moskva_poselok_kievski...
# 10914  https://move.ru/objects/moskva_ulica_krylatski...
# 10105  https://move.ru/objects/predstavlyaem_vashemu_...
# 1564   https://move.ru/objects/moskva_gorod_zelenogra...
# ...                                                  ...
# 7364   https://move.ru/objects/nomer_151_5-k_kvartira...
# 7366   https://move.ru/objects/nomer_206_5-k_kvartira...
# 8291   https://move.ru/objects/prodaetsya_5-komn_kvar...
# 8345   https://move.ru/objects/nomer_141_5-k_kvartira...
# 5357   https://move.ru/objects/moskva_ulica_bronnaya_...
#
#                                                Заголовок  \
# 321    Продаю пентхаус, 550 м², Москва, шоссе Коровин...
# 115                   Продаю квартиру, 42 м², Москва, 17
# 10914  Продаем квартиру, 410 м², Москва, улица Крылат...
# ...

# %%
# срез до 3 элемента в описательном минисете
described_data.iloc[:3]
# Out:
#        Год постройки  Кол-во просмотров  Кол-во просмотров сегодня  \
# count    7025.000000       13001.000000                7224.000000
# mean     2001.139786          94.524190                   1.844546
# std        25.060692         199.666472                   2.712400
#
#        Количество этажей  Количество комнат     Этажность   Номер этажа
# count       12510.000000       13001.000000  13001.000000  13001.000000
# mean           17.488649           1.974848     17.444043      8.624798
# std            19.682982           0.912510      9.728213      6.693463

# %%
# вывести год построки по индексу 101 квартиры
dataset.loc[101, 'Год постройки']
# Out:
# 1898.0

# %%
# Шаблон для взятия среза в хаотично пронумеровнном датасете 
sorted_dataset = dataset.sort_values('Количество комнат', ascending=False)
sorted_dataset.iloc[:100]

# %%
# выводим строки, удовлетворяющие условию
dataset[dataset['Год постройки']>2010]
# Out:
#                                                      url  \
# 1      https://move.ru/objects/prodaetsya_2-komn_kvar...
# 2      https://move.ru/objects/prodaetsya_2-komn_kvar...
# 3      https://move.ru/objects/prodaetsya_2-komn_kvar...
# 4      https://move.ru/objects/prodaetsya_3-komn_kvar...
# 5      https://move.ru/objects/prodaetsya_3-komn_kvar...
# ...                                                  ...
# 12996  https://move.ru/objects/prodaetsya_1-komnatnay...
# 12997  https://move.ru/objects/prodaetsya_1-komnatnay...
# 12998  https://move.ru/objects/prodaetsya_2-komnatnay...
# 12999  https://move.ru/objects/prodaetsya_1-komnatnay...
# 13000  https://move.ru/objects/prodaetsya_1-komnatnay...
#
#                                                Заголовок  \
# 1      Продам 2-комнатную квартиру, 83.2 м², Москва, ...
# 2      Продаю 2-комнатную квартиру, 89.6 м², Москва, ...
# 3      Продам 2-комнатную квартиру, 55.8 м², Москва, ...
# ...

# %%
# создаём фильтр по условию содержания подстроки в строке
filter = dataset['Адрес'].apply(lambda x: 'Тагильская' in x)
filter
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12996    False
# 12997    False
# 12998    False
# 12999    False
# 13000    False
# Name: Адрес, Length: 13001, dtype: bool

# %%
# применяем фильтр к датасету
filtred_dataset = dataset[filter]
filtred_dataset
# Out:
#                                                      url  \
# 103    https://move.ru/objects/prodaetsya_1-komn_kvar...
# 104    https://move.ru/objects/prodaetsya_3-komn_kvar...
# 207    https://move.ru/objects/prodaetsya_3-komn_kvar...
# 310    https://move.ru/objects/prodaetsya_2-komn_kvar...
# 311    https://move.ru/objects/prodaetsya_2-komn_kvar...
# ...                                                  ...
# 11592  https://move.ru/objects/prodaetsya_3-komn_kvar...
# 11593  https://move.ru/objects/prodaetsya_1-komn_kvar...
# 11799  https://move.ru/objects/prodaetsya_3-komn_kvar...
# 11902  https://move.ru/objects/prodaetsya_3-komn_kvar...
# 12827  https://move.ru/objects/prodaetsya_1-komn_kvar...
#
#                                                Заголовок  \
# 103    Продаю 1-комнатную квартиру, 39.4 м², Москва, ...
# 104    Продается 3-комнатная квартира, 78.2 м², Москв...
# 207    Продам 3-комнатную квартиру, 78.2 м², Москва, ...
# ...

# %%
# выводим адрес отфильтрованного датасета
filtred_dataset['Адрес']
# Out:
# 103      г. Москва\nТагильская улица\n4
# 104      г. Москва\nТагильская улица\n4
# 207      г. Москва\nТагильская улица\n4
# 310      г. Москва\nТагильская улица\n4
# 311      г. Москва\nТагильская улица\n4
#                       ...
# 11592    г. Москва\nТагильская улица\n4
# 11593    г. Москва\nТагильская улица\n4
# 11799    г. Москва\nТагильская улица\n4
# 11902    г. Москва\nТагильская улица\n4
# 12827    г. Москва\nТагильская улица\n4
# Name: Адрес, Length: 149, dtype: object

# %%
# создаём подсет из колонок и типов данных в них
dtypes = dataset.dtypes
dtypes
# Out:
# url                               object
# Заголовок                         object
# Новостройка                       object
# Этап строительства                object
# Год постройки                    float64
# Класс жилья                       object
# МЦК                               object
# Кол-во просмотров                  int64
# Кол-во просмотров сегодня        float64
# Описание                          object
# Информация                        object
# Адрес                             object
# Тип здания                        object
# Количество этажей                float64
# Цена                              object
# цена за м²                        object
# Комиссия агенту                   object
# Количество комнат                  int64
# Этажность                          int64
# Тип объекта                       object
# Тип объявления                    object
# Общая площадь                     object
# Дата публикации                   object
# ...

# %%
# оставляем только колонки без типа данных object и переписываем переменную
dtypes = dtypes[dtypes!='object']
dtypes
# Out:
# Год постройки                float64
# Кол-во просмотров              int64
# Кол-во просмотров сегодня    float64
# Количество этажей            float64
# Количество комнат              int64
# Этажность                      int64
# Номер этажа                    int64
# dtype: object

# %%
# из основного датасета выводим только колонки с индексами подсета выше (только числовые)
dataset_num = dataset[dtypes.index]
dataset_num
# Out:
#        Год постройки  Кол-во просмотров  Кол-во просмотров сегодня  \
# 0             1967.0                125                        3.0
# 1             2020.0                202                        1.0
# 2             2018.0                 20                        1.0
# 3             2019.0                 15                        1.0
# 4             2017.0                 42                        3.0
# ...              ...                ...                        ...
# 12996         2019.0                 50                        1.0
# 12997         2019.0                 48                        1.0
# 12998         2019.0                 60                        1.0
# 12999         2019.0                 50                        1.0
# 13000         2019.0                 47                        1.0
#
#        Количество этажей  Количество комнат  Этажность  Номер этажа
# 0                    5.0                  1          5            3
# ...

# %%
# способ фильтрации через лямбду
filter = dataset['Адрес'].apply(lambda x: 'Тагильская' in x)
filtred_dataset = dataset[filter]

# Нестандартная фильтрация с помощью дополнительный функции
def is_address_correct(address):
  return 'Тагильская' in address

mask = dataset['Адрес'].apply(is_address_correct)
filtred_dataset = dataset[mask]

# %%
# Шаблон фильтрации числовых колонок
dtypes = dataset.dtypes
num_dtypes = dtypes[dtypes!='object']
new_columns = num_dtypes.index
filtred_dataset = dataset[num_dtypes.index]

# %%
# применяем фильтр к датасету, чтобы найти подстроку Мира в столбце Адрес и вывести все строки датасета удовлетворяющие запросу
filter = dataset['Адрес'].apply(lambda x: 'Мира' in x)
dataset[filter]
# Out:
#                                                      url  \
# 240    https://move.ru/objects/moskva_prospekt_mira_2...
# 241    https://move.ru/objects/moskva_prospekt_mira_2...
# 773    https://move.ru/objects/prodaetsya_4-komnatnay...
# 1374   https://move.ru/objects/moskva_mira_prospekt_d...
# 1404   https://move.ru/objects/moskva_mira_prospekt_d...
# 1413   https://move.ru/objects/moskva_mira_prospekt_d...
# 1653   https://move.ru/objects/moskva_mira_prospekt_d...
# 1894   https://move.ru/objects/moskva_prospekt_mira_d...
# 2255   https://move.ru/objects/moskva_prospekt_mira_d...
# 2339   https://move.ru/objects/moskva_prospekt_mira_d...
# 2772   https://move.ru/objects/moskva_mira_prospekt_d...
# 2895   https://move.ru/objects/moskva_mira_prospekt_d...
# 3259   https://move.ru/objects/moskva_mira_prospekt_d...
# 3264   https://move.ru/objects/moskva_mira_prospekt_d...
# 3266   https://move.ru/objects/moskva_mira_prospekt_d...
# ...
